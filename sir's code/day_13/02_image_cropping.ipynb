# %%
import matplotlib.pyplot as plt 
import numpy as np
from PIL import Image
import cv2

# %%
cat = cv2.imread('../images/cat.jpg')
cat = cv2.cvtColor(cat, cv2.COLOR_BGR2RGB)
plt.imshow(cat)

# %%
img = cv2.imread('../images/caves.jpg')

# %%
plt.imshow(img)

# %%
cropped = plt.imshow(img[100:300, 100:350])
cropped

# %% [markdown]
# ### Relative cropping

# %%
height, width, _ = img.shape

# %%
height, width
# Out:
# (534, 400)

# %%
plt.imshow(img[int(width*0.25): int(width*0.75), int(height*0.25): int(height*0.75)])

# %% [markdown]
# ### Cropping image

# %%
from PIL import Image

img = Image.open('../images/dog.jpg')

# %%
cropped_img = img.crop((100, 100, 300, 300))
# startx, starty, endx, endy

# %%
cropped_img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
