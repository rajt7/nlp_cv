# %%
import keras
from keras.datasets import mnist
from keras import Sequential
from keras import layers 
import numpy as np

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_6 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense_6 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### Train the Model

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 9s 19ms/step - loss: 0.3659 - accuracy: 0.8891 - val_loss: 0.0823 - val_accuracy: 0.9757
# Epoch 2/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.1121 - accuracy: 0.9661 - val_loss: 0.0561 - val_accuracy: 0.9848
# Epoch 3/15
# 422/422 [==============================] - 8s 18ms/step - loss: 0.0854 - accuracy: 0.9730 - val_loss: 0.0473 - val_accuracy: 0.9883
# Epoch 4/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0713 - accuracy: 0.9777 - val_loss: 0.0396 - val_accuracy: 0.9888
# Epoch 5/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0601 - accuracy: 0.9817 - val_loss: 0.0364 - val_accuracy: 0.9897
# Epoch 6/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0550 - accuracy: 0.9834 - val_loss: 0.0363 - val_accuracy: 0.9903
# Epoch 7/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0486 - accuracy: 0.9844 - val_loss: 0.0340 - val_accuracy: 0.9907
# Epoch 8/15
# 422/422 [==============================] - 7s 17ms/step - loss: 0.0469 - accuracy: 0.9851 - val_loss: 0.0360 - val_accuracy: 0.9903
# Epoch 9/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0423 - accuracy: 0.9870 - val_loss: 0.0330 - val_accuracy: 0.9912
# Epoch 10/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0400 - accuracy: 0.9869 - val_loss: 0.0311 - val_accuracy: 0.9912
# Epoch 11/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0386 - accuracy: 0.9881 - val_loss: 0.0335 - val_accuracy: 0.9900
# Epoch 12/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.0313 - val_accuracy: 0.9920
# Epoch 13/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.0309 - val_accuracy: 0.9918
# Epoch 14/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0327 - accuracy: 0.9891 - val_loss: 0.0280 - val_accuracy: 0.9927
# Epoch 15/15
# 422/422 [==============================] - 7s 18ms/step - loss: 0.0319 - accuracy: 0.9898 - val_loss: 0.0289 - val_accuracy: 0.9932
