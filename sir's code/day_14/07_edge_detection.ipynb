# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../images/draw.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Perform edge detection (low threshold, high threshold)
edges = cv2.Canny(img, 100, 200)
plt.imshow(edges)

# %%
plt.figure(figsize=(16, 10))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Circle Image

# %%
img = cv2.imread('../images/circle.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

edges = cv2.Canny(img, 50, 150)

plt.figure(figsize=(16, 10))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Building Image

# %%
img = cv2.imread('../images/buildings.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

edges = cv2.Canny(img, 240, 250)

plt.figure(figsize=(16, 10))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Laplacian Edge Detection

# %%
import numpy as np

# %%
img = cv2.imread('../images/draw.png')

# %%
kernel = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])

edges = cv2.filter2D(img, -1, kernel)

plt.figure(figsize=(16, 10))

plt.subplot(121)
plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122),
plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Using PIL Library

# %%
from PIL import Image, ImageFilter

# %%
image = Image.open('../images/draw.png')
gray_img = image.convert("L")
gray_img
# Out:
# <PIL.Image.Image image mode=L size=655x543>

# %%
edges_find_edges = gray_img.filter(ImageFilter.FIND_EDGES)
edges_find_edges
# Out:
# <PIL.Image.Image image mode=L size=655x543>
