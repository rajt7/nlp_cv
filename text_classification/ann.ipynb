# %%
import pandas as pd

yelp_data_path = '/home/dai/33/nlp_cv/data/sentiment+labelled+sentences/sentiment labelled sentences/yelp_labelled.txt'

df = pd.read_csv(yelp_data_path, names=['text', 'label'], sep='\t')
df.head()
# Out:
#                                                 text  label
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# 1    500
# 0    500
# Name: count, dtype: int64

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split

X = df['text'].values
y = df['label'].values

sentences_train, sentences_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=1000)

# %% [markdown]
# ### Baseline Model (Using ML)

# %% [markdown]
# #### Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
cv = CountVectorizer()

X_train = cv.fit_transform(sentences_train)
X_test = cv.transform(sentences_test)

X_train
# Out:
# <750x1714 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7368 stored elements in Compressed Sparse Row format>

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.796

# %% [markdown]
# #### Tf-IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

X_train = tfidf.fit_transform(sentences_train)
X_test = tfidf.transform(sentences_test)

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.768

# %% [markdown]
# ### Deep Learning Era

# %% [markdown]
# #### Simple Model in Keras
#
# **Text is converted using Bag of Words**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

X_train = tfidf.fit_transform(sentences_train)
X_test = tfidf.transform(sentences_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

keras.backend.clear_session()
model = Sequential()

model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                17150
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 17161 (67.04 KB)
# Trainable params: 17161 (67.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                17150
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 17161 (67.04 KB)
# Trainable params: 17161 (67.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
X_train
# Out:
# <750x1714 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7368 stored elements in Compressed Sparse Row format>

# %%
history = model.fit(X_train.toarray(), y_train, epochs=100, verbose=1,
                    validation_data=(X_test.toarray(), y_test), batch_size=10)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 6ms/step - loss: 0.6910 - accuracy: 0.5267 - val_loss: 0.6886 - val_accuracy: 0.5360
# Epoch 2/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6698 - accuracy: 0.7160 - val_loss: 0.6737 - val_accuracy: 0.6280
# Epoch 3/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6263 - accuracy: 0.8533 - val_loss: 0.6479 - val_accuracy: 0.7040
# Epoch 4/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.5623 - accuracy: 0.8880 - val_loss: 0.6132 - val_accuracy: 0.7400
# Epoch 5/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.4894 - accuracy: 0.9320 - val_loss: 0.5813 - val_accuracy: 0.7360
# Epoch 6/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4170 - accuracy: 0.9480 - val_loss: 0.5492 - val_accuracy: 0.7400
# Epoch 7/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.3513 - accuracy: 0.9613 - val_loss: 0.5216 - val_accuracy: 0.7600
# Epoch 8/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2943 - accuracy: 0.9693 - val_loss: 0.5009 - val_accuracy: 0.7720
# Epoch 9/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2480 - accuracy: 0.9760 - val_loss: 0.4828 - val_accuracy: 0.7800
# Epoch 10/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2091 - accuracy: 0.9813 - val_loss: 0.4682 - val_accuracy: 0.7840
# Epoch 11/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 0.9853 - val_loss: 0.4605 - val_accuracy: 0.7880
# Epoch 12/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1518 - accuracy: 0.9893 - val_loss: 0.4525 - val_accuracy: 0.7880
# Epoch 13/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.9907 - val_loss: 0.4474 - val_accuracy: 0.7920
# Epoch 14/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1132 - accuracy: 0.9947 - val_loss: 0.4445 - val_accuracy: 0.7880
# Epoch 15/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9960 - val_loss: 0.4408 - val_accuracy: 0.7880
# Epoch 16/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0867 - accuracy: 0.9960 - val_loss: 0.4415 - val_accuracy: 0.7880
# Epoch 17/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9960 - val_loss: 0.4396 - val_accuracy: 0.7880
# Epoch 18/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9973 - val_loss: 0.4431 - val_accuracy: 0.8000
# Epoch 19/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9973 - val_loss: 0.4407 - val_accuracy: 0.7920
# Epoch 20/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 0.9987 - val_loss: 0.4425 - val_accuracy: 0.7840
# Epoch 21/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9987 - val_loss: 0.4454 - val_accuracy: 0.7880
# Epoch 22/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.9987 - val_loss: 0.4463 - val_accuracy: 0.7880
# Epoch 23/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9987 - val_loss: 0.4487 - val_accuracy: 0.7920
# Epoch 24/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0360 - accuracy: 0.9987 - val_loss: 0.4510 - val_accuracy: 0.7920
# Epoch 25/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9987 - val_loss: 0.4536 - val_accuracy: 0.7960
# Epoch 26/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9987 - val_loss: 0.4571 - val_accuracy: 0.7960
# Epoch 27/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 0.9987 - val_loss: 0.4580 - val_accuracy: 0.7960
# Epoch 28/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9987 - val_loss: 0.4625 - val_accuracy: 0.7960
# Epoch 29/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9987 - val_loss: 0.4641 - val_accuracy: 0.7960
# Epoch 30/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.4687 - val_accuracy: 0.7960
# Epoch 31/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4723 - val_accuracy: 0.7920
# Epoch 32/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.4758 - val_accuracy: 0.7920
# Epoch 33/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 0.7920
# Epoch 34/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.4810 - val_accuracy: 0.7920
# Epoch 35/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4835 - val_accuracy: 0.7920
# Epoch 36/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.7920
# Epoch 37/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.7880
# Epoch 38/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.7880
# Epoch 39/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4989 - val_accuracy: 0.7880
# Epoch 40/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.7880
# Epoch 41/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.7920
# Epoch 42/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.5070 - val_accuracy: 0.7920
# Epoch 43/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.7880
# Epoch 44/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5134 - val_accuracy: 0.7920
# Epoch 45/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.7920
# Epoch 46/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5205 - val_accuracy: 0.7880
# Epoch 47/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.5235 - val_accuracy: 0.7880
# Epoch 48/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5273 - val_accuracy: 0.7880
# Epoch 49/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5305 - val_accuracy: 0.7880
# Epoch 50/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5336 - val_accuracy: 0.7840
# Epoch 51/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5371 - val_accuracy: 0.7840
# Epoch 52/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.7880
# Epoch 53/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5436 - val_accuracy: 0.7880
# Epoch 54/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5463 - val_accuracy: 0.7840
# Epoch 55/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5507 - val_accuracy: 0.7880
# Epoch 56/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5532 - val_accuracy: 0.7880
# Epoch 57/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5574 - val_accuracy: 0.7880
# Epoch 58/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5595 - val_accuracy: 0.7880
# Epoch 59/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5641 - val_accuracy: 0.7880
# Epoch 60/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5660 - val_accuracy: 0.7880
# Epoch 61/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.7920
# Epoch 62/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5726 - val_accuracy: 0.7920
# Epoch 63/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.7920
# Epoch 64/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.7920
# Epoch 65/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5826 - val_accuracy: 0.7920
# Epoch 66/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5871 - val_accuracy: 0.7920
# Epoch 67/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5913 - val_accuracy: 0.7880
# Epoch 68/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5933 - val_accuracy: 0.7920
# Epoch 69/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5973 - val_accuracy: 0.7920
# Epoch 70/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5994 - val_accuracy: 0.7920
# Epoch 71/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6038 - val_accuracy: 0.7920
# Epoch 72/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6065 - val_accuracy: 0.7920
# Epoch 73/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.7960
# Epoch 74/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.7880
# Epoch 75/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6156 - val_accuracy: 0.7880
# Epoch 76/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6198 - val_accuracy: 0.7880
# Epoch 77/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6228 - val_accuracy: 0.7880
# Epoch 78/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6271 - val_accuracy: 0.7920
# Epoch 79/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6287 - val_accuracy: 0.7880
# Epoch 80/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.7880
# Epoch 81/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6359 - val_accuracy: 0.7920
# Epoch 82/100
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6404 - val_accuracy: 0.7920
# Epoch 83/100
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6428 - val_accuracy: 0.7920
# Epoch 84/100
# 75/75 [==============================] - 0s 3ms/step - loss: 9.8879e-04 - accuracy: 1.0000 - val_loss: 0.6451 - val_accuracy: 0.7920
# Epoch 85/100
# 75/75 [==============================] - 0s 3ms/step - loss: 9.4361e-04 - accuracy: 1.0000 - val_loss: 0.6494 - val_accuracy: 0.7960
# Epoch 86/100
# 75/75 [==============================] - 0s 3ms/step - loss: 9.0293e-04 - accuracy: 1.0000 - val_loss: 0.6512 - val_accuracy: 0.7880
# Epoch 87/100
# 75/75 [==============================] - 0s 4ms/step - loss: 8.6135e-04 - accuracy: 1.0000 - val_loss: 0.6561 - val_accuracy: 0.7960
# Epoch 88/100
# 75/75 [==============================] - 0s 3ms/step - loss: 8.2304e-04 - accuracy: 1.0000 - val_loss: 0.6577 - val_accuracy: 0.7920
# Epoch 89/100
# 75/75 [==============================] - 0s 4ms/step - loss: 7.8405e-04 - accuracy: 1.0000 - val_loss: 0.6611 - val_accuracy: 0.7960
# Epoch 90/100
# 75/75 [==============================] - 0s 3ms/step - loss: 7.5194e-04 - accuracy: 1.0000 - val_loss: 0.6642 - val_accuracy: 0.7960
# Epoch 91/100
# 75/75 [==============================] - 0s 3ms/step - loss: 7.1894e-04 - accuracy: 1.0000 - val_loss: 0.6689 - val_accuracy: 0.7960
# Epoch 92/100
# 75/75 [==============================] - 0s 3ms/step - loss: 6.8744e-04 - accuracy: 1.0000 - val_loss: 0.6695 - val_accuracy: 0.7920
# Epoch 93/100
# 75/75 [==============================] - 0s 3ms/step - loss: 6.5725e-04 - accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.7960
# Epoch 94/100
# 75/75 [==============================] - 0s 3ms/step - loss: 6.2652e-04 - accuracy: 1.0000 - val_loss: 0.6769 - val_accuracy: 0.7960
# Epoch 95/100
# 75/75 [==============================] - 0s 3ms/step - loss: 5.9928e-04 - accuracy: 1.0000 - val_loss: 0.6823 - val_accuracy: 0.7960
# Epoch 96/100
# 75/75 [==============================] - 0s 3ms/step - loss: 5.7318e-04 - accuracy: 1.0000 - val_loss: 0.6851 - val_accuracy: 0.7960
# Epoch 97/100
# 75/75 [==============================] - 0s 3ms/step - loss: 5.4810e-04 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.7960
# Epoch 98/100
# 75/75 [==============================] - 0s 3ms/step - loss: 5.2423e-04 - accuracy: 1.0000 - val_loss: 0.6901 - val_accuracy: 0.7960
# Epoch 99/100
# 75/75 [==============================] - 0s 4ms/step - loss: 5.0393e-04 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.7960
# Epoch 100/100
# 75/75 [==============================] - 0s 3ms/step - loss: 4.7807e-04 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.7960

# %%
loss, accuracy = model.evaluate(X_train.toarray(), y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test.toarray(), y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Training Accuracy: 1.0000
# Testing Accuracy:  0.7960

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()


plot_history(history)

# %% [markdown]
# #### Simple Model in Keras
#
# **Using Embedding Layer**

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences_train)

X_train = tokenizer.texts_to_sequences(sentences_train)
X_test = tokenizer.texts_to_sequences(sentences_test)

vocab_size = len(tokenizer.word_index) + 1

# %%
from keras.preprocessing.sequence import pad_sequences

maxlen = 100

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
X_train.shape
# Out:
# (750, 100)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Embedding

embeddding_dim = 50

keras.backend.clear_session()
model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=embeddding_dim, input_length=maxlen))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

print(model.summary())

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=20,
                    verbose=0,
                    batch_size=10)

loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))

plot_history(history)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 50)           87350
#
#  flatten (Flatten)           (None, 5000)              0
#
#  dense (Dense)               (None, 10)                50010
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 137371 (536.61 KB)
# Trainable params: 137371 (536.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training Accuracy: 1.0000
# Testing Accuracy:  0.7280

# %% [markdown]
# **Using Global Max Pooling 1D**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Embedding, GlobalMaxPooling1D

embeddding_dim = 50

keras.backend.clear_session()
model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=embeddding_dim, input_length=maxlen))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

print(model.summary())

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=20,
                    verbose=0,
                    batch_size=10)

loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print(f"Training Accuracy: {accuracy:.4f}")
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print(f"Testing Accuracy:  {accuracy:.4f}")

plot_history(history)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 50)           87350
#
#  global_max_pooling1d (Glob  (None, 50)                0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 10)                510
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 87871 (343.25 KB)
# Trainable params: 87871 (343.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training Accuracy: 1.0000
# Testing Accuracy:  0.8240

# %%
text1 = 'Best Service ever! It was great, I will definitely recommend it.'
text2 = 'That was the worst pizza.'

def predict_review(text):
    tokenized_text = tokenizer.texts_to_sequences(text)
    sequenced_text = pad_sequences(tokenized_text, padding='post', maxlen=maxlen)
    y_pred = model.predict(sequenced_text, verbose=0)
    return y_pred

ans = predict_review(text1)
ans.shape
# Out:
# (64, 1)

# %%
text1 = 'Best Service ever! It was great, I will definitely recommend it.'

tokenizer1 = tokenizer.texts_to_sequences(text1)
sequenced1 = pad_sequences(tokenizer1, maxlen=maxlen)

y_pred = model.predict(sequenced1, verbose=0)
y_pred.shape
# Out:
# (64, 1)
